# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('Uploaded')
# Out:
#      <input type="file" id="files-583b2316-227d-4996-a99d-320c015bb75e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-583b2316-227d-4996-a99d-320c015bb75e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving src_img.jpg to src_img (4).jpg
# Saving template.jpg to template (1).jpg
# Uploaded
# Uploaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
src = cv2.imread('src_img.jpg')
template = cv2.imread('template.jpg')
print('SOURCE IMAGE')
cv2_imshow(src)
print('TEMPLATE')
cv2_imshow(template)
# Out:
# SOURCE IMAGE
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FE94BC32C50>
# TEMPLATE
# <PIL.Image.Image image mode=RGB size=137x140 at 0x7FE94B3A6EB8>

# %%
sift = cv2.xfeatures2d.SIFT_create()
kp1, des1 = sift.detectAndCompute(src,None)
kp2, des2 = sift.detectAndCompute(template,None)

# %%
bf = cv2.BFMatcher()
matches = bf.knnMatch(des1,des2, k=2)

# %%
good = []
for m,n in matches:
    if m.distance < 0.3*n.distance:
        good.append([m])

# %%
res2 = cv2.drawMatchesKnn(src,kp1,template,kp2,good,None,flags=2)
cv2_imshow(res2)
# Out:
# <PIL.Image.Image image mode=RGB size=1161x768 at 0x7FE949512D68>
